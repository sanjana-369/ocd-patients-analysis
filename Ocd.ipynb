# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df=pd.read_csv('OCD Patient Dataset_ Demographics & Clinical Data.csv')

df
# Out:
#       Patient ID  Age  Gender  Ethnicity Marital Status  Education Level  \
# 0           1018   32  Female    African         Single     Some College
# 1           2406   69    Male    African       Divorced     Some College
# 2           1188   57    Male   Hispanic       Divorced   College Degree
# 3           6200   27  Female   Hispanic        Married   College Degree
# 4           5824   56  Female   Hispanic        Married      High School
# ...          ...  ...     ...        ...            ...              ...
# 1495        5374   38    Male   Hispanic       Divorced   College Degree
# 1496        5013   19  Female   Hispanic       Divorced  Graduate Degree
# 1497        6089   40    Male      Asian        Married     Some College
# 1498        3808   37  Female  Caucasian        Married     Some College
# 1499        2221   18    Male  Caucasian         Single      High School
#
#      OCD Diagnosis Date  Duration of Symptoms (months) Previous Diagnoses  \
# ...

# %%
df.shape
# Out:
# (1500, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 17 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Patient ID                     1500 non-null   int64
#  1   Age                            1500 non-null   int64
#  2   Gender                         1500 non-null   object
#  3   Ethnicity                      1500 non-null   object
#  4   Marital Status                 1500 non-null   object
#  5   Education Level                1500 non-null   object
#  6   OCD Diagnosis Date             1500 non-null   object
#  7   Duration of Symptoms (months)  1500 non-null   int64
#  8   Previous Diagnoses             1252 non-null   object
#  9   Family History of OCD          1500 non-null   object
#  10  Obsession Type                 1500 non-null   object
#  11  Compulsion Type                1500 non-null   object
# ...

# %%
df.dtypes
# Out:
# Patient ID                        int64
# Age                               int64
# Gender                           object
# Ethnicity                        object
# Marital Status                   object
# Education Level                  object
# OCD Diagnosis Date               object
# Duration of Symptoms (months)     int64
# Previous Diagnoses               object
# Family History of OCD            object
# Obsession Type                   object
# Compulsion Type                  object
# Y-BOCS Score (Obsessions)         int64
# Y-BOCS Score (Compulsions)        int64
# Depression Diagnosis             object
# Anxiety Diagnosis                object
# Medications                      object
# dtype: object

# %%
df.describe()
# Out:
#         Patient ID          Age  Duration of Symptoms (months)  \
# count  1500.000000  1500.000000                    1500.000000
# mean   5541.254000    46.781333                     121.745333
# std    2562.389469    16.830321                      67.404610
# min    1017.000000    18.000000                       6.000000
# 25%    3338.000000    32.000000                      64.000000
# 50%    5539.500000    47.000000                     121.000000
# 75%    7745.500000    61.000000                     178.000000
# max    9995.000000    75.000000                     240.000000
#
#        Y-BOCS Score (Obsessions)  Y-BOCS Score (Compulsions)
# count                1500.000000                  1500.00000
# mean                   20.048000                    19.62600
# std                    11.823884                    11.78287
# min                     0.000000                     0.00000
# 25%                    10.000000                     9.00000
# ...

# %%
ethinicity_mapping = {'Caucasian':0, 'African':1, 'Asian':2, 'Hispanic':3}
df['Ethnicity'] = df['Ethnicity'].map(ethinicity_mapping)
print(df.head())
# Out:
#    Patient ID  Age  Gender  Ethnicity Marital Status Education Level  \
# 0        1018   32  Female          1         Single    Some College
# 1        2406   69    Male          1       Divorced    Some College
# 2        1188   57    Male          3       Divorced  College Degree
# 3        6200   27  Female          3        Married  College Degree
# 4        5824   56  Female          3        Married     High School
#
#   OCD Diagnosis Date  Duration of Symptoms (months) Previous Diagnoses  \
# 0         2016-07-15                            203                MDD
# 1         2017-04-28                            180                NaN
# 2         2018-02-02                            173                MDD
# 3         2014-08-25                            126               PTSD
# 4         2022-02-20                            168               PTSD
#
#   Family History of OCD Obsession Type Compulsion Type  \
# 0                    No   Harm-related        Checking
# ...

# %%
gender_mapping={'Male':0, 'Female':1}

df['Gender']=df['Gender'].map(gender_mapping)

print(df.head())
# Out:
#    Patient ID  Age  Gender  Ethnicity Marital Status Education Level  \
# 0        1018   32       1          1         Single    Some College
# 1        2406   69       0          1       Divorced    Some College
# 2        1188   57       0          3       Divorced  College Degree
# 3        6200   27       1          3        Married  College Degree
# 4        5824   56       1          3        Married     High School
#
#   OCD Diagnosis Date  Duration of Symptoms (months) Previous Diagnoses  \
# 0         2016-07-15                            203                MDD
# 1         2017-04-28                            180                NaN
# 2         2018-02-02                            173                MDD
# 3         2014-08-25                            126               PTSD
# 4         2022-02-20                            168               PTSD
#
#   Family History of OCD Obsession Type Compulsion Type  \
# 0                    No   Harm-related        Checking
# ...

# %%
marital_status_mapping={'Single':0, 'Divorced':1, 'Married':2}

df['Marital Status']=df['Marital Status'].map(marital_status_mapping)

df.head()
# Out:
#    Patient ID  Age  Gender  Ethnicity  Marital Status Education Level  \
# 0        1018   32       1          1               0    Some College
# 1        2406   69       0          1               1    Some College
# 2        1188   57       0          3               1  College Degree
# 3        6200   27       1          3               2  College Degree
# 4        5824   56       1          3               2     High School
#
#   OCD Diagnosis Date  Duration of Symptoms (months) Previous Diagnoses  \
# 0         2016-07-15                            203                MDD
# 1         2017-04-28                            180                NaN
# 2         2018-02-02                            173                MDD
# 3         2014-08-25                            126               PTSD
# 4         2022-02-20                            168               PTSD
#
#   Family History of OCD Obsession Type Compulsion Type  \
# 0                    No   Harm-related        Checking
# ...

# %%
previous_diagnosis_mapping={'None':0, 'GDD':1, 'MDD':2, 'Pacic Disorder':3, 'PTSD':4}

df['Previous Diagnoses']=df['Previous Diagnoses'].map(previous_diagnosis_mapping)

df.head()
# Out:
#    Patient ID  Age  Gender  Ethnicity  Marital Status Education Level  \
# 0        1018   32       1          1               0    Some College
# 1        2406   69       0          1               1    Some College
# 2        1188   57       0          3               1  College Degree
# 3        6200   27       1          3               2  College Degree
# 4        5824   56       1          3               2     High School
#
#   OCD Diagnosis Date  Duration of Symptoms (months)  Previous Diagnoses  \
# 0         2016-07-15                            203                 2.0
# 1         2017-04-28                            180                 NaN
# 2         2018-02-02                            173                 2.0
# 3         2014-08-25                            126                 4.0
# 4         2022-02-20                            168                 4.0
#
#   Family History of OCD Obsession Type Compulsion Type  \
# ...

# %%
family_history_mapping={'Yes':1, 'No':0}


df['Family History of OCD']=df['Family History of OCD'].map(family_history_mapping)

df.head()
# Out:
#    Patient ID  Age  Gender  Ethnicity  Marital Status Education Level  \
# 0        1018   32       1          1               0    Some College
# 1        2406   69       0          1               1    Some College
# 2        1188   57       0          3               1  College Degree
# 3        6200   27       1          3               2  College Degree
# 4        5824   56       1          3               2     High School
#
#   OCD Diagnosis Date  Duration of Symptoms (months)  Previous Diagnoses  \
# 0         2016-07-15                            203                 2.0
# 1         2017-04-28                            180                 NaN
# 2         2018-02-02                            173                 2.0
# 3         2014-08-25                            126                 4.0
# 4         2022-02-20                            168                 4.0
#
#    Family History of OCD Obsession Type Compulsion Type  \
# ...

# %%
obsession_mapping={'Contamination':0, 'Ham-related':1, 'Hoarding':2, 'Religious':3, 'Symmentry':4}


df['Obsession Type']=df['Obsession Type'].map(obsession_mapping)

df.head()
# Out:
#    Patient ID  Age  Gender  Ethnicity  Marital Status Education Level  \
# 0        1018   32       1          1               0    Some College
# 1        2406   69       0          1               1    Some College
# 2        1188   57       0          3               1  College Degree
# 3        6200   27       1          3               2  College Degree
# 4        5824   56       1          3               2     High School
#
#   OCD Diagnosis Date  Duration of Symptoms (months)  Previous Diagnoses  \
# 0         2016-07-15                            203                 2.0
# 1         2017-04-28                            180                 NaN
# 2         2018-02-02                            173                 2.0
# 3         2014-08-25                            126                 4.0
# 4         2022-02-20                            168                 4.0
#
#    Family History of OCD  Obsession Type Compulsion Type  \
# ...

# %%
depression_diag = {'Yes':1, 'No':0}
anxiety_diag = {'Yes':1, 'No':0}
df['Depression Diagnosis'] = df['Depression Diagnosis'].map(depression_diag)
df['Anxiety Diagnosis'] = df['Anxiety Diagnosis'].map(anxiety_diag)
print(df.head())
# Out:
#    Patient ID  Age  Gender  Ethnicity  Marital Status Education Level  \
# 0        1018   32       1          1               0    Some College
# 1        2406   69       0          1               1    Some College
# 2        1188   57       0          3               1  College Degree
# 3        6200   27       1          3               2  College Degree
# 4        5824   56       1          3               2     High School
#
#   OCD Diagnosis Date  Duration of Symptoms (months)  Previous Diagnoses  \
# 0         2016-07-15                            203                 2.0
# 1         2017-04-28                            180                 NaN
# 2         2018-02-02                            173                 2.0
# 3         2014-08-25                            126                 4.0
# 4         2022-02-20                            168                 4.0
#
#    Family History of OCD  Obsession Type Compulsion Type  \
# ...

# %%
column_drop = [0,1,5,6,7,11,16]
df.drop(df.columns[column_drop], axis=1, inplace=True)
print(df.head())
# Out:
#    Gender  Ethnicity  Marital Status  Previous Diagnoses  \
# 0       1          1               0                 2.0
# 1       0          1               1                 NaN
# 2       0          3               1                 2.0
# 3       1          3               2                 4.0
# 4       1          3               2                 4.0
#
#    Family History of OCD  Obsession Type  Y-BOCS Score (Obsessions)  \
# 0                      0             NaN                         17
# 1                      1             NaN                         21
# 2                      0             0.0                          3
# 3                      1             NaN                         14
# 4                      1             2.0                         39
#
#    Y-BOCS Score (Compulsions)  Depression Diagnosis  Anxiety Diagnosis
# 0                          10                     1                  1
# ...

# %%
X = df.iloc[:,:-2].values
X
# Out:
# array([[ 1.,  1.,  0., ..., nan, 17., 10.],
#        [ 0.,  1.,  1., ..., nan, 21., 25.],
#        [ 0.,  3.,  1., ...,  0.,  3.,  4.],
#        ...,
#        [ 0.,  2.,  2., ...,  0.,  2., 15.],
#        [ 1.,  0.,  2., ...,  0., 16.,  7.],
#        [ 0.,  0.,  0., ...,  2., 22., 34.]])

# %%
Y = df.iloc[:, -2].values
Y
# Out:
# array([1, 1, 0, ..., 1, 1, 1], dtype=int64)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=None)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.svm import SVC

from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold

# %%
from sklearn.ensemble import HistGradientBoostingClassifier


model = HistGradientBoostingClassifier()


cv_result = cross_val_score(model, X_train, Y_train, cv=kfold, scoring='accuracy')
print(cv_result)

# %%
models = []
models.append(('LRA', LogisticRegression()))
models.append(('LDA', LinearDiscriminantAnalysis()))
models.append(('DTC', DecisionTreeClassifier()))
models.append(('KNB', KNeighborsClassifier()))
models.append(('GNB', GaussianNB()))
models.append(('PCT', Perceptron()))
models.append(('SVM', SVC(gamma='auto')))

# %%
names = []
results = []
res = []

for name, model in models:
  kfold = StratifiedKFold(n_splits=50, random_state=None)
  cv_results = cross_val_score(model, X_train, Y_train, cv=kfold, scoring='accuracy')
  names.append(name)
  results.append(cv_results)
  res.append(cv_results.mean())
  print('%s : %f'%(name,cv_results.mean()*100))

# %%
import pandas as pd
from sklearn.impute import SimpleImputer

# Assume df is your DataFrame
# Example: Impute "Previous Diagnoses" using the most frequent diagnosis (mode)
imputer = SimpleImputer(strategy='most_frequent')
df['Previous Diagnoses'] = imputer.fit_transform(df[['Previous Diagnoses']])

# Example: Impute "Obsession Type" using the most frequent type (mode)
df['Obsession Type'] = imputer.fit_transform(df[['Obsession Type']])

# For numerical columns, you could use mean or median imputation:
imputer_num = SimpleImputer(strategy='mean')
df['Y-BOCS Score (Obsessions)'] = imputer_num.fit_transform(df[['Y-BOCS Score (Obsessions)']])

# %%
import numpy as np

# Check for missing values (NaNs) in X_train
print("Missing values in X_train:")
print(np.isnan(X_train).sum())  # Counts the number of NaNs in X_train

# Check for missing values (NaNs) in Y_train
print("Missing values in Y_train:")
print(np.isnan(Y_train).sum())  # Co

# %%
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import StratifiedKFold, cross_val_score

# Impute missing values in X_train using mean strategy
X_imputer = SimpleImputer(strategy='mean')
X_train_imputed = X_imputer.fit_transform(X_train)

# If Y_train has missing values, use most_frequent strategy (or you can use 'mean' or 'constant')
Y_imputer = SimpleImputer(strategy='most_frequent')
Y_train_imputed = Y_imputer.fit_transform(Y_train.reshape(-1, 1)).ravel()

# Create a Logistic Regression pipeline (with imputation)
pipeline = make_pipeline(
    SimpleImputer(strategy='mean'),  # Impute X_train with mean
    LogisticRegression()  # Logistic Regression model
)

# Perform cross-validation with StratifiedKFold
kfold = StratifiedKFold(n_splits=50, random_state=None)

# Perform cross-validation and print results
cv_result = cross_val_score(pipeline, X_train_imputed, Y_train_imputed, cv=kfold, scoring='accuracy')
print(cv_result)
# Out:
# [0.71428571 0.38095238 0.52380952 0.71428571 0.71428571 0.66666667
#  0.61904762 0.42857143 0.42857143 0.52380952 0.76190476 0.61904762
#  0.57142857 0.47619048 0.42857143 0.57142857 0.38095238 0.52380952
#  0.57142857 0.52380952 0.57142857 0.33333333 0.57142857 0.52380952
#  0.57142857 0.33333333 0.52380952 0.61904762 0.42857143 0.52380952
#  0.52380952 0.47619048 0.52380952 0.57142857 0.47619048 0.47619048
#  0.61904762 0.47619048 0.38095238 0.61904762 0.52380952 0.57142857
#  0.52380952 0.57142857 0.47619048 0.28571429 0.38095238 0.47619048
#  0.47619048 0.57142857]

# %%
df.isnull().sum()
# Out:
# Gender                          0
# Ethnicity                       0
# Marital Status                  0
# Previous Diagnoses            859
# Family History of OCD           0
# Obsession Type                613
# Y-BOCS Score (Obsessions)       0
# Y-BOCS Score (Compulsions)      0
# Depression Diagnosis            0
# Anxiety Diagnosis               0
# dtype: int64

# %%
import pandas as pd
from sklearn.impute import SimpleImputer

# Assume df is your DataFrame
# Example: Impute "Previous Diagnoses" using the most frequent diagnosis (mode)
imputer = SimpleImputer(strategy='most_frequent')
df['Previous Diagnoses'] = imputer.fit_transform(df[['Previous Diagnoses']])

# Example: Impute "Obsession Type" using the most frequent type (mode)
df['Obsession Type'] = imputer.fit_transform(df[['Obsession Type']])

# For numerical columns, you could use mean or median imputation:
imputer_num = SimpleImputer(strategy='mean')
df['Y-BOCS Score (Obsessions)'] = imputer_num.fit_transform(df[['Y-BOCS Score (Obsessions)']])

# %%
df.isnull().sum()
# Out:
# Gender                        0
# Ethnicity                     0
# Marital Status                0
# Previous Diagnoses            0
# Family History of OCD         0
# Obsession Type                0
# Y-BOCS Score (Obsessions)     0
# Y-BOCS Score (Compulsions)    0
# Depression Diagnosis          0
# Anxiety Diagnosis             0
# dtype: int64

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.svm import SVC

from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold

# %%
import xgboost
from xgboost import XGBClassifier
classifier = XGBClassifier()
classifier.fit(X_train, Y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
# !pip install xgboost

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
Y_pred = classifier.predict(X_test)
accuracy = accuracy_score(Y_test, Y_pred)
print('Accuracy Score : ',accuracy*100)
cm = confusion_matrix(Y_test, Y_pred)
print(cm)
# Out:
# Accuracy Score :  49.77777777777778
# [[ 94 112]
#  [114 130]]

# %%
true_positive = cm[0,0]
false_positive = cm[0,1]
true_negative = cm[1,1]
false_negative = cm[1,0]
sensitivity = true_positive / (true_positive+false_positive)
specificity = true_negative / (true_negative+false_negative)
LR_pos = sensitivity / (1-specificity)
LR_neg = (1-sensitivity)/specificity

print('Sensitivity of Dataset : ',sensitivity)
print('Specificity of Dataset : ',specificity)
print('LR+ : ',LR_pos)
print('LR- : ',LR_neg)
# Out:
# Sensitivity of Dataset :  0.4563106796116505
# Specificity of Dataset :  0.5327868852459017
# LR+ :  0.9766649633793222
# LR- :  1.0204630321135175
